# %% [markdown]
# **MEDICAL INSURANCE DATASET**

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# IMPORTING DATASET

# %%
df=pd.read_csv('/content/insurance.csv')

# %% [markdown]
# CHECKING 5 ROW

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# Target Variable:Charges column

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# ROWS=1338
# COLUMNS=7

# %% [markdown]
# CHECKING THE DATATYPES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# categorical columns:sex,smoker,region

# %% [markdown]
# **continuous columns**

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %% [markdown]
# **checking the null values**

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# There is no null values in medical insurance dataset

# %% [markdown]
# **Checking for duplicates in the dataset**

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# There is only single duplicate row so,there is no large impact in keeping that row .so,we won't delete it.

# %% [markdown]
# # **Exploratory Data Analysis for Categorical Column**

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
df['sex'].value_counts().plot.pie(autopct='%1.1f%%', colors=['pink', 'blue'], labels=['female', 'male'])
plt.title("Gender distribution")
# Out:
# Text(0.5, 1.0, 'Gender distribution')

# %% [markdown]
# from the above pie chart it is obeserved that proportion of males is 49.5% and that of female is 50.5%. this says

# %%
df['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
sns.countplot(x=df['children'], palette="muted")
# Out:
# <ipython-input-13-e14f82eab505>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['children'], palette="muted")
# <Axes: xlabel='children', ylabel='count'>

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
df['smoker'].value_counts().plot.pie(autopct='%1.1f%%', colors=['pink', 'blue'], labels=['no', 'yes'])
plt.title("distribution of smoker")
# Out:
# Text(0.5, 1.0, 'distribution of smoker')

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df['region'].value_counts().plot.pie(autopct='%1.1f%%', colors=['pink', 'blue','red','black'], labels=df['region'].value_counts().index)
plt.title("distribution of smoker")
# Out:
# Text(0.5, 1.0, 'distribution of smoker')

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex',hue='smoker',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.set_style('whitegrid')
sns.countplot(x='age',hue='smoker',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex',hue='children',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=df,x='sex',hue='smoker',palette='hls')
plt.title('Distribution of smokers and non-smokers across Gender')
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
sns.countplot(data=df,x='sex',hue='region',palette='flare')
plt.title('Distribution of Gender across the regions')
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
sns.countplot(data=df,x='children',hue='smoker',palette='rocket')
plt.title('Distribution of smokers among individuals according to their number of children')
# Out:
# Text(0.5, 1.0, 'Distribution of smokers among individuals according to their number of children')

# %%
sns.countplot(data=df,x='children',hue='region',palette='mako')
plt.title('Distribution of individuals based on the number of children according to the region')
# Out:
# Text(0.5, 1.0, 'Distribution of individuals based on the number of children according to the region')

# %%
sns.countplot(data=df,x='region',hue='smoker',palette='viridis')
plt.title('Distribution of smokers and non-smokers according to the region')
# Out:
# Text(0.5, 1.0, 'Distribution of smokers and non-smokers according to the region')

# %% [markdown]
# **ANALYSIS OF CONTINUOUS DATA**

# %%
df['age'].plot(kind='box',color='black')
# Out:
# <Axes: >

# %%
sns.displot(data=df,x='age',bins = 20,kde=True)

# %%
sns.displot(data=df,x='bmi',kde=True)

# %%
df['charges'].plot(kind='box',color='violet')
# Out:
# <Axes: >

# %%
sns.displot(data=df,x='charges',kde=True)

# %% [markdown]
# **REMOVE OUTLAYERS**

# %%
df['charges'] = np.log(df['charges'])

# Plot the transformed distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['charges'],bins = 30, kde=True,color='red')
plt.xlabel("Log(Charges)")
plt.ylabel("Count")
plt.title("Distribution of Log-Transformed Charges")
plt.show()

# %%
df.describe().T
# Out:
#            count       mean        std        min        25%        50%  \
# age       1338.0  39.207025  14.049960  18.000000  27.000000  39.000000
# bmi       1338.0  30.663397   6.098187  15.960000  26.296250  30.400000
# children  1338.0   1.094918   1.205493   0.000000   0.000000   1.000000
# charges   1338.0   9.098659   0.919527   7.022756   8.463853   9.146552
#
#                 75%        max
# age       51.000000  64.000000
# bmi       34.693750  53.130000
# children   2.000000   5.000000
# charges    9.719558  11.063045

# %%
q1 = df['bmi'].quantile(0.25)
q3 = df['bmi'].quantile(0.75)
iqr = q3 - q1
lower = q1-1.5*iqr
upper = q3+1.5*iqr

df= df[(df['bmi'] >= lower) & (df['bmi'] <= upper)]

# %%
df['bmi'].plot(kind='box',color='red')
# Out:
# <Axes: >

# %%
sns.boxplot(data=df,x='sex',y='age',hue='sex',palette='hls')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=df,x='sex',y='bmi',hue='sex',palette='hls')
# Out:
# <Axes: xlabel='sex', ylabel='bmi'>

# %%
sns.boxplot(data=df,x='smoker',y='age',hue='sex',palette='hls')
# Out:
# <Axes: xlabel='smoker', ylabel='age'>

# %%
sns.boxplot(data=df,x='smoker',y='bmi',hue='sex',palette='hls')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
sns.scatterplot(data=df,x='age',y='bmi',hue='bmi',palette='hls')
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(data=df,x='age',y='charges',hue='charges',palette='hls')
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.boxplot(data=df,x='region',y='charges',hue='sex',palette='hls')
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
sns.boxplot(data=df,x='sex',y='charges',hue='sex',palette='hls')
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
df.shape
# Out:
# (1329, 7)

# %%
df['sex'].value_counts()
# Out:
# sex
# male      670
# female    659
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1058
# yes     271
# Name: count, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region
# southeast    357
# northwest    325
# southwest    324
# northeast    323
# Name: count, dtype: int64

# %% [markdown]
# **ENCODING**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()


df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region   charges
# 0   19    0  27.900         0       1       3  9.734176
# 1   18    1  33.770         1       0       2  7.453302
# 2   28    1  33.000         3       0       2  8.400538
# 3   33    1  22.705         0       0       1  9.998092
# 4   32    1  28.880         0       0       1  8.260197

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    670
# 0    659
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# 0    1058
# 1     271
# Name: count, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region
# 2    357
# 1    325
# 3    324
# 0    323
# Name: count, dtype: int64

# %% [markdown]
# **FEATURE SCALING**

# %%
df.describe().T
# Out:
#            count       mean        std        min        25%        50%  \
# age       1329.0  39.203913  14.047835  18.000000  27.000000  39.000000
# sex       1329.0   0.504138   0.500171   0.000000   0.000000   1.000000
# bmi       1329.0  30.537348   5.919946  15.960000  26.220000  30.300000
# children  1329.0   1.096313   1.207928   0.000000   0.000000   1.000000
# smoker    1329.0   0.203913   0.403057   0.000000   0.000000   0.000000
# region    1329.0   1.513168   1.106532   0.000000   1.000000   2.000000
# charges   1329.0   9.097041   0.916474   7.022756   8.463427   9.144342
#
#                 75%        max
# age       51.000000  64.000000
# sex        1.000000   1.000000
# bmi       34.485000  46.750000
# children   2.000000   5.000000
# smoker     0.000000   1.000000
# region     2.000000   3.000000
# charges    9.716344  11.044407

# %%
from sklearn.preprocessing import StandardScaler

target = 'charges'
scaler = StandardScaler()
feature_columns = [col for col in df.columns if col != target]
df[feature_columns] = scaler.fit_transform(df[feature_columns])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-003f604b0fee> in <cell line: 0>()
#       3 target = 'charges'
#       4 scaler = StandardScaler()
# ----> 5 feature_columns = [col for col in df.columns if col != target]
#       6 df[feature_columns] = scaler.fit_transform(df[feature_columns])
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#         age       sex       bmi  children    smoker    region   charges
# 0 -1.438764 -1.008311 -0.445670 -0.907940  1.975869  1.344193  9.734176
# 1 -1.509976  0.991757  0.546267 -0.079764 -0.506106  0.440128  7.453302
# 2 -0.797855  0.991757  0.416149  1.576587 -0.506106  0.440128  8.400538
# 3 -0.441794  0.991757 -1.323542 -0.907940 -0.506106 -0.463937  9.998092
# 4 -0.513006  0.991757 -0.280065 -0.907940 -0.506106 -0.463937  8.260197

# %% [markdown]
# **train-test-split**

# %%
y=df['charges']
x=df.drop(columns={'charges'})

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=40)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (1063, 6)
# (1063,)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (266, 6)
# (266,)

# %%
from sklearn.linear_model import LinearRegression

# create a linear regression model
model = LinearRegression()

# fit the model to the training data
model.fit(x_train, y_train)
r2_score = model.score(x_test,y_test)
print(r2_score*100,'%')
# Out:
# 79.02034057341434 %

# %% [markdown]
# 1. Data Overview
# Dataset: Medical insurance dataset with 1,338 rows and 7 columns.
#
# Target Variable: charges (the medical insurance cost).
#
# Feature Types:
#
# Categorical: sex, smoker, region
#
# Numerical: age, bmi, children
#
# 🟢 Insight: The dataset is clean — no null values and only one duplicate (which was kept).
#
# 📊 2. Exploratory Data Analysis (EDA)
# ➤ Categorical Analysis:
# Sex: ~50.5% female, ~49.5% male.
#
# Smoker: Majority are non-smokers.
#
# Region: Data is distributed across four regions (likely U.S. regions).
#
# Children: Distribution shows varied number of children, mostly 0–2.
#
# 🟢 Insight:
#
# The dataset is balanced in terms of gender.
#
# Smoker status appears frequently in the analysis, suggesting it’s an important feature.
#
# ➤ Continuous Analysis:
# age, bmi, and charges distributions were explored.
#
# Box plots and histograms used for detecting outliers.
#
# Log transformation applied to charges to correct skewness.
#
# 🟢 Insight:
#
# Insurance charges are right-skewed — high-cost outliers (likely smokers or older individuals).
#
# BMI distribution shows potential outliers.
#
# 🛠️ 3. Data Preprocessing
# ➤ Steps taken:
# Outlier handling (visually inspected via boxplots).
#
# Encoding categorical variables.
#
# Feature scaling (though not detailed here, usually StandardScaler or MinMaxScaler is applied).
#
# Train-test split for model training and evaluation.
#
# 🟢 Insight:
#
# Correct transformations were made to prepare the data for regression models.
#
# 📉 4. Data Visualizations – Insights Discovered
# Several grouped countplots were made:
#
# Smokers pay much higher charges — visualized across age, children, and region.
#
# Gender distribution among smokers is relatively even.
#
# Children do not drastically affect smoking likelihood.
#
# Regional plots show slight differences in smoking rates.
#
# 🟢 Key Insight:
#
# Smoking is the most significant driver of insurance charges.
# Other contributors: Age and BMI.
#
# 📈 5. Distribution Analysis of charges
# Original distribution was highly skewed.
#
# After log transformation, the distribution was normalized.
#
# 🟢 Insight:
#
# Applying log helped prepare charges for linear modeling techniques.
#
# ✅ Summary of Key Insights from the Project
#
#
# Smokers incur significantly higher charges.
#
#
# Older individuals have higher medical costs.
#
# BMI can lead to increased charges.
#
# Slight variations, no strong correlation.
#
# Small or no significant effect.
#
# Slight regional variance, not major.
